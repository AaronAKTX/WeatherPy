# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head(50)
# Out:
#     City_ID              City Country                 Date      Lat       Lng  \
# 0         0            Hobart      AU  2021-12-04 02:15:44 -42.8794  147.3294
# 1         1         Busselton      AU  2021-12-04 02:19:33 -33.6500  115.3333
# 2         2           Ushuaia      AR  2021-12-04 02:19:33 -54.8000  -68.3000
# 3         3            Albany      US  2021-12-04 02:17:52  42.6001  -73.9662
# 4         4            Usinsk      RU  2021-12-04 02:19:34  65.9939   57.5281
# 5         5     Srednekolymsk      RU  2021-12-04 02:19:35  67.4500  153.6833
# 6         6         Belyy Yar      RU  2021-12-04 02:19:35  53.6039   91.3903
# 7         7           Rikitea      PF  2021-12-04 02:19:35 -23.1203 -134.9692
# 8         8    Vestmannaeyjar      IS  2021-12-04 02:19:36  63.4427  -20.2734
# 9         9       Springfield      US  2021-12-04 02:19:36  37.2153  -93.2982
# 10       10            Huambo      AO  2021-12-04 02:19:37 -12.7761   15.7392
# 11       11         Mahebourg      MU  2021-12-04 02:19:37 -20.4081   57.7000
# 12       12    Ribeira Grande      PT  2021-12-04 02:19:37  38.5167  -28.7000
# 13       13            Tiznit      MA  2021-12-04 02:19:38  29.5833   -9.5000
# 14       14            Olinda      BR  2021-12-04 02:19:39  -8.0089  -34.8553
# 15       15     Mar Del Plata      AR  2021-12-04 02:19:39 -38.0023  -57.5575
# 16       16           Qaanaaq      GL  2021-12-04 02:15:14  77.4840  -69.3632
# 17       17     Prince Rupert      CA  2021-12-04 02:19:40  54.3161 -130.3201
# 18       18          Khatanga      RU  2021-12-04 02:19:40  71.9667  102.5000
# 19       19            Faanui      PF  2021-12-04 02:19:40 -16.4833 -151.7500
# 20       20    Kulhudhuffushi      MV  2021-12-04 02:19:41   6.6221   73.0700
# 21       21         Mount Isa      AU  2021-12-04 02:19:41 -20.7333  139.5000
# 22       22             Seoul      KR  2021-12-04 02:16:38  37.5683  126.9778
# 23       23              Poum      NC  2021-12-04 02:19:42 -20.2333  164.0167
# 24       24       Port Alfred      ZA  2021-12-04 02:19:42 -33.5906   26.8910
# 25       25              Hilo      US  2021-12-04 02:17:27  19.7297 -155.0900
# 26       26      Richards Bay      ZA  2021-12-04 02:19:43 -28.7830   32.0377
# 27       27         Carnarvon      AU  2021-12-04 02:19:43 -24.8667  113.6333
# 28       28      Puerto Ayora      EC  2021-12-04 02:19:44  -0.7393  -90.3518
# 29       29            Lethem      GY  2021-12-04 02:19:44   3.3803  -59.7968
# 30       30              Chuy      UY  2021-12-04 02:19:45 -33.6971  -53.4616
# 31       31       Fort Nelson      CA  2021-12-04 02:19:45  58.8053 -122.7002
# 32       32          Hermanus      ZA  2021-12-04 02:19:46 -34.4187   19.2345
# 33       33           Illapel      CL  2021-12-04 02:19:46 -31.6308  -71.1653
# 34       34            Lompoc      US  2021-12-04 02:19:01  34.6391 -120.4579
# 35       35       Provideniya      RU  2021-12-04 02:19:47  64.3833 -173.3000
# 36       36              Nome      US  2021-12-04 02:19:47  64.5011 -165.4064
# 37       37             Moron      AR  2021-12-04 02:19:48 -34.6534  -58.6198
# 38       38   Haines Junction      CA  2021-12-04 02:19:48  60.7522 -137.5108
# 39       39      Longyearbyen      SJ  2021-12-04 02:18:50  78.2186   15.6401
# 40       40        Kaitangata      NZ  2021-12-04 02:19:49 -46.2817  169.8464
# 41       41       New Norfolk      AU  2021-12-04 02:19:49 -42.7826  147.0587
# 42       42         Pemangkat      ID  2021-12-04 02:19:50   1.1667  108.9667
# 43       43        Chokurdakh      RU  2021-12-04 02:19:50  70.6333  147.9167
# 44       44           Isangel      VU  2021-12-04 02:19:50 -19.5500  169.2667
# 45       45         Ostrovnoy      RU  2021-12-04 02:19:51  68.0531   39.5131
# 46       46             Natal      BR  2021-12-04 02:19:51  -5.7950  -35.2094
# 47       47            Bereda      ES  2021-12-04 02:19:52  43.2686   -7.5406
# 48       48  Glenwood Springs      US  2021-12-04 02:19:52  39.5505 -107.3248
# 49       49        Twin Falls      US  2021-12-04 02:19:52  42.3505 -114.6445
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 0      59.11        62          40        4.00
# 1      76.08        42           8        7.25
# 2      53.26        47          20       23.02
# 3      31.08        70           4        6.85
# 4     -17.73        92          11        7.38
# 5     -14.53        97         100       12.66
# 6      33.69        82           0        4.47
# 7      76.73        73          43       15.35
# 8      33.85        79          79       12.21
# 9      63.84        85          75        1.99
# 10     60.60        94         100        3.44
# 11     79.25        88          20        3.44
# 12     65.25        81         100       11.65
# 13     53.91        42           0        4.47
# 14     82.13        74          40        9.22
# 15     59.09        85          90        5.01
# 16      6.67        92         100        3.49
# 17     40.69        88          90        8.05
# 18    -19.35        97         100       15.82
# 19     81.41        71          38       17.74
# 20     81.28        76          13        3.09
# 21    100.17        19          40       18.41
# 22     40.57        42           0        4.61
# 23     81.03        75          30       17.31
# 24     64.83        79         100        6.29
# 25     80.33        79          20       11.50
# 26     70.41        83         100        5.61
# 27     78.87        69           0       11.50
# 28     67.68        91          64        5.79
# 29     79.25        67          77        8.48
# 30     60.37        86          61        6.69
# 31    -13.41        84          75        0.00
# 32     61.90        77          89       12.93
# 33     63.14        62           0        1.90
# 34     56.57        81          90        4.61
# 35     30.18        98         100       13.09
# 36      8.67        78          90       21.85
# 37     70.00        78         100        4.00
# 38    -13.05        77         100        0.00
# 39     35.44        60          40       20.71
# 40     59.41        97         100        5.84
# 41     58.75        57          88        5.01
# 42     82.99        75         100       11.30
# 43    -27.22        96         100        9.95
# 44     87.91        58          40        6.91
# 45     20.21        76         100        3.67
# 46     81.25        89          75       10.36
# 47     54.00       100          97        9.62
# 48     44.06        54           5        0.51
# 49     40.89        75           1        8.05

# %%
# get the data types
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.35)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=200, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent Cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of wind speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 1         1       Busselton      AU  2021-12-04 02:19:33 -33.6500  115.3333
# 7         7         Rikitea      PF  2021-12-04 02:19:35 -23.1203 -134.9692
# 11       11       Mahebourg      MU  2021-12-04 02:19:37 -20.4081   57.7000
# 14       14          Olinda      BR  2021-12-04 02:19:39  -8.0089  -34.8553
# 19       19          Faanui      PF  2021-12-04 02:19:40 -16.4833 -151.7500
# 20       20  Kulhudhuffushi      MV  2021-12-04 02:19:41   6.6221   73.0700
# 23       23            Poum      NC  2021-12-04 02:19:42 -20.2333  164.0167
# 25       25            Hilo      US  2021-12-04 02:17:27  19.7297 -155.0900
# 27       27       Carnarvon      AU  2021-12-04 02:19:43 -24.8667  113.6333
# 29       29          Lethem      GY  2021-12-04 02:19:44   3.3803  -59.7968
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 1      76.08        42           8        7.25
# 7      76.73        73          43       15.35
# 11     79.25        88          20        3.44
# 14     82.13        74          40        9.22
# 19     81.41        71          38       17.74
# 20     81.28        76          13        3.09
# 23     81.03        75          30       17.31
# 25     80.33        79          20       11.50
# 27     78.87        69           0       11.50
# 29     79.25        67          77        8.48

# %%
preferred_cities_df.count()
# Out:
# City_ID       130
# City          130
# Country       130
# Date          130
# Lat           130
# Lng           130
# Max Temp      130
# Humidity      130
# Cloudiness    130
# Wind Speed    130
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(50)
# Out:
#                   City Country  Max Temp      Lat       Lng Hotel Name
# 1            Busselton      AU     76.08 -33.6500  115.3333
# 7              Rikitea      PF     76.73 -23.1203 -134.9692
# 11           Mahebourg      MU     79.25 -20.4081   57.7000
# 14              Olinda      BR     82.13  -8.0089  -34.8553
# 19              Faanui      PF     81.41 -16.4833 -151.7500
# 20      Kulhudhuffushi      MV     81.28   6.6221   73.0700
# 23                Poum      NC     81.03 -20.2333  164.0167
# 25                Hilo      US     80.33  19.7297 -155.0900
# 27           Carnarvon      AU     78.87 -24.8667  113.6333
# 29              Lethem      GY     79.25   3.3803  -59.7968
# 42           Pemangkat      ID     82.99   1.1667  108.9667
# 44             Isangel      VU     87.91 -19.5500  169.2667
# 46               Natal      BR     81.25  -5.7950  -35.2094
# 59                Miri      MY     77.14   4.4148  114.0089
# 63             Siparia      TT     77.79  10.1333  -61.5000
# 64              Atuona      PF     78.93  -9.8000 -139.0333
# 69               Buala      SB     84.36  -8.1450  159.5921
# 73               Kapaa      US     75.52  22.0752 -159.3190
# 87               Canoa      DO     76.41  18.3550  -71.1585
# 90              Avarua      CK     77.05 -21.2078 -159.7750
# 92              Teknaf      BD     76.24  20.8624   92.3058
# 95               Vaini      TO     84.36 -21.2000 -175.2000
# 103           Bengkulu      ID     82.53  -3.8004  102.2655
# 105               Poya      NC     83.01 -21.3500  165.1500
# 112          Quelimane      MZ     77.18 -17.8786   36.8883
# 113           Bac Lieu      VN     75.04   9.2850  105.7244
# 114            Iralaya      HN     77.04  15.0000  -83.2333
# 115    Bambous Virieux      MU     79.21 -20.3428   57.7575
# 119     Cabo San Lucas      MX     79.52  22.8909 -109.9124
# 122         Georgetown      MY     82.33   5.4112  100.3354
# 123          Hithadhoo      MV     81.72  -0.6000   73.0833
# 129     Saint-Philippe      RE     76.55 -21.3585   55.7679
# 135         Butaritari      KI     82.29   3.0707  172.7902
# 140               Juba      SS     78.60   4.8517   31.5825
# 146           Almeirim      BR     80.29  -1.5233  -52.5817
# 153         The Valley      AI     81.10  18.2170  -63.0578
# 154          Kavaratti      IN     81.16  10.5669   72.6420
# 161        Panama City      PA     82.06   8.9936  -79.5197
# 162             Neiafu      TO     84.88 -18.6500 -173.9833
# 163               Tual      ID     83.68  -5.6667  132.7500
# 164               Bima      ID     84.78  -8.4667  118.7167
# 165         Coahuayana      MX     80.08  18.7333 -103.6833
# 167             Madang      PG     88.39  -5.2246  145.7966
# 191       Christchurch      NZ     82.60 -43.5333  172.6333
# 196              Larap      PH     77.29  14.2990  122.6504
# 204           Souillac      MU     79.36 -20.5167   57.5167
# 209              Coxim      BR     78.28 -18.5067  -54.7600
# 213            Mayumba      GA     77.14  -3.4320   10.6554
# 215            Honiara      SB     84.63  -9.4333  159.9500
# 216  Puerto El Triunfo      SV     78.96  13.2833  -88.5500

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        print(hotels["results"][0]["name"])
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Observatory Guest House
# People ThankYou
# Shandrani Beachcomber Resort & Spa
# Hotel Albergue de Olinda
# Bora-Bora Pearl Beach Resort & Spa
# Haajy Guest House 1
# Gîte kajeon
# Hilo Hawaiian Hotel
# Hospitality Carnarvon
# Savannah Inn
# Ramah Kost KITA
# Tanna Lodge
# Villa Park Hotel | Natal
# Mega Hotel, Miri
# Brook Gardens
# Villa Enata
# Maringe Lagoon Lodge
# Sheraton Kauai Coconut Beach Resort
# Col julia
# Paradise Inn
# Forestry Guesthouse
# Keleti Beach Resort
# Grage Hotel Bengkulu
# Hotel not found... skipping.
# Hotel Flamingo
# Khách sạn Sài Gòn Bạc Liêu
# Iglesia morava renovada
# Casa Tia Villa
# Hotel Tesoro Los Cabos
# Cititel Penang
# Scoop Guest House
# Chambres d'hôte "La Trinité"
# Isles Sunset Lodge
# ROYAL PALACE HOTEL - JUBA
# Ricácio Hotel
# CeBlue Villas & Beach Resort
# Hotels in Lakshadweep Islands
# Riande Urban Hotel
# Mystic Sands Beachfront Accommodation
# Grand Vilia Hotel
# Lambitu Hotel
# El rranchito michuacan de ocampos
# Comfort Inn Hotel
# The George
# Montemayor Cove
# Shanti Maurice Resort & Spa
# Hotel Avenida
# LIKWALE LODGE
# Heritage Park Hotel
# Hotel Jardin
# Hotel Juba
# Green hotel
# Kimbe Bay Hotel
# hotêl doufoulougou
# Hotel Delta
# Hotel not found... skipping.
# Lorengau Harbourside Hotel
# Omadhoo Inn
# ASTON Denpasar Hotel & Convention Center
# Hotel Nusantara Nabire
# Nusa Island Retreat
# Hotel not found... skipping.
# Atlantis Hotel
# Pousada Avenida
# Salinas Park Resort Maçarico AP101
# KOPKAR Hotel Bintang Sintuk
# Hotel Rio Vista
# Hotel Star Residency
# Ethos Inn
# Hotel Plaza Providencia
# SEGAYA PROPERTY
# INN NEW HORIZON
# Reason Inn
# KOSAN UNGU UNSIK
# Divi Village Golf & Beach Resort
# Sapriadi Appy
# Tour Eiffel Hotel Benin
# ALETHEIA Appartement Sinnamary
# Bale Ocasa hotel
# Selina Pedasi
# Mercure Padang
# Casa de Campo Resort and Villas
# Hotel Olako
# RH HOTEL (4 Star)
# Kost Pria
# Penginapan Kim
# Beira Terrace Hotel
# Hotel not found... skipping.
# Sunrise Attitude Hotel
# Hotel Colonial
# MONLEK GUEST HOUSE
# Nuli Sapi
# Taloa Heights
# Cj's Travellers Inn
# Hotel Wixel
# Welcomhotel By ITC Hotels, Bay Island, Port Blair
# Shelly Bay Resort
# Hostal Iván y yailet
# In Wewak Boutique Hotel
# Hotel Kou-Bugny
# Bird of Paradise Hotel & Apartments
# Akwa Reef Lodge
# Storyboard Beach Resort
# Howard Johnson by Wyndham Plaza Hotel Mayorazgo
# Sea Lounge! Bar, Club & Restaurant
# Enviro Villa
# Parkir Mobil Wisata CAS Water Park
# Raybow International Hotel
# Ballistic Islet
# Hotel not found... skipping.
# Amaloh Boutique Resort
# Blue Ridge Beach Resort
# The Bungalow Sawtell
# Mushola Al Huda
# Hotel not found... skipping.
# Mess P.Milu
# Groote Eylandt Lodge
# Daru Lodge
# Hotel not found... skipping.
# Hotel Potosí Los Mirtos
# Puri Brata
# RedDoorz Syariah near Taman Berlabuh Tarakan
# Lakatoro Palm Lodge
# HS Hotsson Smart Acapulco
# Gite de la RYAWA
# Pin Drop Hotel
# Jose Luis Villalobos De La Cruz
# Ilha Praia Hotel
# Black and Crystal Sand Campsite
# Hotel Uribia

# %%
hotel_df.head(50)
# Out:
#                   City Country  Max Temp      Lat       Lng  \
# 1            Busselton      AU     76.08 -33.6500  115.3333
# 7              Rikitea      PF     76.73 -23.1203 -134.9692
# 11           Mahebourg      MU     79.25 -20.4081   57.7000
# 14              Olinda      BR     82.13  -8.0089  -34.8553
# 19              Faanui      PF     81.41 -16.4833 -151.7500
# 20      Kulhudhuffushi      MV     81.28   6.6221   73.0700
# 23                Poum      NC     81.03 -20.2333  164.0167
# 25                Hilo      US     80.33  19.7297 -155.0900
# 27           Carnarvon      AU     78.87 -24.8667  113.6333
# 29              Lethem      GY     79.25   3.3803  -59.7968
# 42           Pemangkat      ID     82.99   1.1667  108.9667
# 44             Isangel      VU     87.91 -19.5500  169.2667
# 46               Natal      BR     81.25  -5.7950  -35.2094
# 59                Miri      MY     77.14   4.4148  114.0089
# 63             Siparia      TT     77.79  10.1333  -61.5000
# 64              Atuona      PF     78.93  -9.8000 -139.0333
# 69               Buala      SB     84.36  -8.1450  159.5921
# 73               Kapaa      US     75.52  22.0752 -159.3190
# 87               Canoa      DO     76.41  18.3550  -71.1585
# 90              Avarua      CK     77.05 -21.2078 -159.7750
# 92              Teknaf      BD     76.24  20.8624   92.3058
# 95               Vaini      TO     84.36 -21.2000 -175.2000
# 103           Bengkulu      ID     82.53  -3.8004  102.2655
# 105               Poya      NC     83.01 -21.3500  165.1500
# 112          Quelimane      MZ     77.18 -17.8786   36.8883
# 113           Bac Lieu      VN     75.04   9.2850  105.7244
# 114            Iralaya      HN     77.04  15.0000  -83.2333
# 115    Bambous Virieux      MU     79.21 -20.3428   57.7575
# 119     Cabo San Lucas      MX     79.52  22.8909 -109.9124
# 122         Georgetown      MY     82.33   5.4112  100.3354
# 123          Hithadhoo      MV     81.72  -0.6000   73.0833
# 129     Saint-Philippe      RE     76.55 -21.3585   55.7679
# 135         Butaritari      KI     82.29   3.0707  172.7902
# 140               Juba      SS     78.60   4.8517   31.5825
# 146           Almeirim      BR     80.29  -1.5233  -52.5817
# 153         The Valley      AI     81.10  18.2170  -63.0578
# 154          Kavaratti      IN     81.16  10.5669   72.6420
# 161        Panama City      PA     82.06   8.9936  -79.5197
# 162             Neiafu      TO     84.88 -18.6500 -173.9833
# 163               Tual      ID     83.68  -5.6667  132.7500
# 164               Bima      ID     84.78  -8.4667  118.7167
# 165         Coahuayana      MX     80.08  18.7333 -103.6833
# 167             Madang      PG     88.39  -5.2246  145.7966
# 191       Christchurch      NZ     82.60 -43.5333  172.6333
# 196              Larap      PH     77.29  14.2990  122.6504
# 204           Souillac      MU     79.36 -20.5167   57.5167
# 209              Coxim      BR     78.28 -18.5067  -54.7600
# 213            Mayumba      GA     77.14  -3.4320   10.6554
# 215            Honiara      SB     84.63  -9.4333  159.9500
# 216  Puerto El Triunfo      SV     78.96  13.2833  -88.5500
#
#                                 Hotel Name
# 1                  Observatory Guest House
# 7                          People ThankYou
# 11      Shandrani Beachcomber Resort & Spa
# 14                Hotel Albergue de Olinda
# 19      Bora-Bora Pearl Beach Resort & Spa
# 20                     Haajy Guest House 1
# 23                             Gîte kajeon
# 25                     Hilo Hawaiian Hotel
# 27                   Hospitality Carnarvon
# 29                            Savannah Inn
# 42                         Ramah Kost KITA
# 44                             Tanna Lodge
# 46                Villa Park Hotel | Natal
# 59                        Mega Hotel, Miri
# 63                           Brook Gardens
# 64                             Villa Enata
# 69                    Maringe Lagoon Lodge
# 73     Sheraton Kauai Coconut Beach Resort
# 87                               Col julia
# 90                            Paradise Inn
# 92                     Forestry Guesthouse
# 95                     Keleti Beach Resort
# 103                   Grage Hotel Bengkulu
# 105
# 112                         Hotel Flamingo
# 113             Khách sạn Sài Gòn Bạc Liêu
# 114                Iglesia morava renovada
# 115                         Casa Tia Villa
# 119                 Hotel Tesoro Los Cabos
# 122                         Cititel Penang
# 123                      Scoop Guest House
# 129           Chambres d'hôte "La Trinité"
# 135                     Isles Sunset Lodge
# 140              ROYAL PALACE HOTEL - JUBA
# 146                          Ricácio Hotel
# 153           CeBlue Villas & Beach Resort
# 154          Hotels in Lakshadweep Islands
# 161                     Riande Urban Hotel
# 162  Mystic Sands Beachfront Accommodation
# 163                      Grand Vilia Hotel
# 164                          Lambitu Hotel
# 165      El rranchito michuacan de ocampos
# 167                      Comfort Inn Hotel
# 191                             The George
# 196                        Montemayor Cove
# 204            Shanti Maurice Resort & Spa
# 209                          Hotel Avenida
# 213                          LIKWALE LODGE
# 215                    Heritage Park Hotel
# 216                           Hotel Jardin

# %%
info_box_template = """
<dl>
<dt>Name</dt><dd>{column1}</dd>
<dt>Another name</dt><dd>{column2}</dd>
</dl>
"""

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

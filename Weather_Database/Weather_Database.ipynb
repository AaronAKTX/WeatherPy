# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
       # time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | tsumeb
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | tirano
# Processing Record 8 of Set 1 | abrau-dyurso
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | naze
# Processing Record 12 of Set 1 | vestmannaeyjar
# Processing Record 13 of Set 1 | yar-sale
# Processing Record 14 of Set 1 | san cristobal
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | annamalainagar
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | sao joao da barra
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | hofn
# Processing Record 27 of Set 1 | provideniya
# Processing Record 28 of Set 1 | sioux lookout
# Processing Record 29 of Set 1 | gazojak
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | santiago
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | te anau
# Processing Record 39 of Set 1 | tambun
# Processing Record 40 of Set 1 | grand gaube
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | barra do garcas
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | faanui
# Processing Record 45 of Set 1 | fortuna
# Processing Record 46 of Set 1 | baglung
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | clyde river
# Processing Record 1 of Set 2 | coihaique
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | port-cartier
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | sao fidelis
# Processing Record 8 of Set 2 | kalmunai
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | ahipara
# Processing Record 11 of Set 2 | olinda
# Processing Record 12 of Set 2 | jinxiang
# Processing Record 13 of Set 2 | srednekolymsk
# Processing Record 14 of Set 2 | broome
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | borovskoy
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | hamilton
# Processing Record 23 of Set 2 | saint-augustin
# Processing Record 24 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | ekibastuz
# Processing Record 28 of Set 2 | lambarene
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | nome
# Processing Record 32 of Set 2 | qovlar
# Processing Record 33 of Set 2 | berdigestyakh
# Processing Record 34 of Set 2 | henties bay
# Processing Record 35 of Set 2 | ardakan
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | coreau
# Processing Record 39 of Set 2 | lakes entrance
# Processing Record 40 of Set 2 | sal rei
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | puerto escondido
# Processing Record 43 of Set 2 | saldanha
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 2 | carutapera
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | melong
# Processing Record 50 of Set 2 | la ronge
# Processing Record 1 of Set 3 | sinnamary
# Processing Record 2 of Set 3 | sambava
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | laurel
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | matay
# Processing Record 7 of Set 3 | salekhard
# Processing Record 8 of Set 3 | hervey bay
# Processing Record 9 of Set 3 | hyeres
# Processing Record 10 of Set 3 | brae
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | neuquen
# Processing Record 13 of Set 3 | sitka
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | pabrade
# Processing Record 16 of Set 3 | pangnirtung
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | namibe
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | catio
# Processing Record 21 of Set 3 | barcelos
# Processing Record 22 of Set 3 | dingzhou
# Processing Record 23 of Set 3 | ankazobe
# Processing Record 24 of Set 3 | umarkot
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | kunming
# Processing Record 27 of Set 3 | sao miguel do araguaia
# Processing Record 28 of Set 3 | axim
# Processing Record 29 of Set 3 | kushiro
# Processing Record 30 of Set 3 | shaunavon
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | nuuk
# Processing Record 33 of Set 3 | caravelas
# Processing Record 34 of Set 3 | mizdah
# Processing Record 35 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 3 | pisco
# Processing Record 37 of Set 3 | iwanai
# Processing Record 38 of Set 3 | belaya gora
# Processing Record 39 of Set 3 | tuatapere
# Processing Record 40 of Set 3 | leningradskiy
# Processing Record 41 of Set 3 | sonkovo
# Processing Record 42 of Set 3 | kozan
# Processing Record 43 of Set 3 | saint-joseph
# Processing Record 44 of Set 3 | soyo
# Processing Record 45 of Set 3 | talnakh
# Processing Record 46 of Set 3 | lazaro cardenas
# Processing Record 47 of Set 3 | odweyne
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | payson
# Processing Record 50 of Set 3 | souillac
# Processing Record 1 of Set 4 | ponta do sol
# Processing Record 2 of Set 4 | narsaq
# Processing Record 3 of Set 4 | buala
# Processing Record 4 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | bac lieu
# Processing Record 8 of Set 4 | guerrero negro
# Processing Record 9 of Set 4 | houma
# Processing Record 10 of Set 4 | huanren
# Processing Record 11 of Set 4 | itarema
# Processing Record 12 of Set 4 | bathsheba
# Processing Record 13 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 4 | bilibino
# Processing Record 15 of Set 4 | taber
# Processing Record 16 of Set 4 | matagami
# Processing Record 17 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 4 | rionero in vulture
# Processing Record 19 of Set 4 | surt
# Processing Record 20 of Set 4 | igarka
# Processing Record 21 of Set 4 | hami
# Processing Record 22 of Set 4 | koslan
# Processing Record 23 of Set 4 | deputatskiy
# Processing Record 24 of Set 4 | haines junction
# Processing Record 25 of Set 4 | liancheng
# Processing Record 26 of Set 4 | ust-kuyga
# Processing Record 27 of Set 4 | adrar
# Processing Record 28 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | saint-die
# City not found. Skipping...
# Processing Record 32 of Set 4 | karnobat
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | osakarovka
# Processing Record 35 of Set 4 | roebourne
# Processing Record 36 of Set 4 | viedma
# Processing Record 37 of Set 4 | aksarka
# Processing Record 38 of Set 4 | thompson
# Processing Record 39 of Set 4 | kahului
# Processing Record 40 of Set 4 | honghu
# Processing Record 41 of Set 4 | mehamn
# Processing Record 42 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 4 | arona
# Processing Record 44 of Set 4 | daru
# Processing Record 45 of Set 4 | berck
# Processing Record 46 of Set 4 | yellowknife
# Processing Record 47 of Set 4 | kruisfontein
# Processing Record 48 of Set 4 | ylivieska
# Processing Record 49 of Set 4 | tiksi
# Processing Record 50 of Set 4 | ziro
# Processing Record 1 of Set 5 | ipanema
# Processing Record 2 of Set 5 | tres palos
# Processing Record 3 of Set 5 | panguipulli
# Processing Record 4 of Set 5 | baft
# Processing Record 5 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 5 | qaanaaq
# Processing Record 7 of Set 5 | pozo colorado
# Processing Record 8 of Set 5 | jiwani
# Processing Record 9 of Set 5 | issenye
# Processing Record 10 of Set 5 | morro bay
# Processing Record 11 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 5 | nyurba
# Processing Record 14 of Set 5 | gat
# Processing Record 15 of Set 5 | arlit
# Processing Record 16 of Set 5 | esso
# Processing Record 17 of Set 5 | severo-kurilsk
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | espanola
# Processing Record 20 of Set 5 | safford
# Processing Record 21 of Set 5 | beringovskiy
# Processing Record 22 of Set 5 | atbasar
# Processing Record 23 of Set 5 | los llanos de aridane
# Processing Record 24 of Set 5 | raudeberg
# Processing Record 25 of Set 5 | peterhead
# Processing Record 26 of Set 5 | vostok
# Processing Record 27 of Set 5 | bubaque
# Processing Record 28 of Set 5 | nemuro
# Processing Record 29 of Set 5 | salalah
# Processing Record 30 of Set 5 | neiafu
# Processing Record 31 of Set 5 | vangaindrano
# Processing Record 32 of Set 5 | urumqi
# Processing Record 33 of Set 5 | salvador
# Processing Record 34 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 5 | cidreira
# Processing Record 36 of Set 5 | port hedland
# Processing Record 37 of Set 5 | alofi
# Processing Record 38 of Set 5 | omboue
# Processing Record 39 of Set 5 | dzilam gonzalez
# Processing Record 40 of Set 5 | labuhan
# Processing Record 41 of Set 5 | semnan
# Processing Record 42 of Set 5 | laguna
# Processing Record 43 of Set 5 | russell
# Processing Record 44 of Set 5 | banda aceh
# Processing Record 45 of Set 5 | nouakchott
# Processing Record 46 of Set 5 | vanavara
# Processing Record 47 of Set 5 | canico
# Processing Record 48 of Set 5 | cumana
# Processing Record 49 of Set 5 | bilma
# Processing Record 50 of Set 5 | saint george
# Processing Record 1 of Set 6 | kilindoni
# Processing Record 2 of Set 6 | oistins
# Processing Record 3 of Set 6 | arrecife
# Processing Record 4 of Set 6 | bornem
# Processing Record 5 of Set 6 | cockburn town
# Processing Record 6 of Set 6 | klaksvik
# Processing Record 7 of Set 6 | dingle
# Processing Record 8 of Set 6 | alassio
# Processing Record 9 of Set 6 | yining
# Processing Record 10 of Set 6 | asfi
# Processing Record 11 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 6 | san patricio
# Processing Record 13 of Set 6 | arraial do cabo
# Processing Record 14 of Set 6 | oksovskiy
# Processing Record 15 of Set 6 | sakakah
# Processing Record 16 of Set 6 | sorland
# Processing Record 17 of Set 6 | half moon bay
# Processing Record 18 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 6 | bastrop
# Processing Record 20 of Set 6 | tautira
# Processing Record 21 of Set 6 | flinders
# Processing Record 22 of Set 6 | veraval
# Processing Record 23 of Set 6 | pacific grove
# Processing Record 24 of Set 6 | awjilah
# Processing Record 25 of Set 6 | sobolevo
# Processing Record 26 of Set 6 | araouane
# Processing Record 27 of Set 6 | bridlington
# Processing Record 28 of Set 6 | bernay
# Processing Record 29 of Set 6 | upernavik
# Processing Record 30 of Set 6 | innisfail
# Processing Record 31 of Set 6 | bredasdorp
# Processing Record 32 of Set 6 | ambon
# Processing Record 33 of Set 6 | taltal
# Processing Record 34 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 6 | gusev
# Processing Record 36 of Set 6 | nieves
# Processing Record 37 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 6 | gryazovets
# Processing Record 39 of Set 6 | west bay
# Processing Record 40 of Set 6 | carbonear
# Processing Record 41 of Set 6 | north bend
# Processing Record 42 of Set 6 | seoul
# Processing Record 43 of Set 6 | port macquarie
# Processing Record 44 of Set 6 | kontagora
# Processing Record 45 of Set 6 | havelock
# Processing Record 46 of Set 6 | husavik
# Processing Record 47 of Set 6 | high prairie
# Processing Record 48 of Set 6 | tafresh
# Processing Record 49 of Set 6 | skegness
# Processing Record 50 of Set 6 | alice springs
# Processing Record 1 of Set 7 | hambantota
# Processing Record 2 of Set 7 | sovetskiy
# Processing Record 3 of Set 7 | altay
# Processing Record 4 of Set 7 | inhambane
# Processing Record 5 of Set 7 | marawi
# Processing Record 6 of Set 7 | bambanglipuro
# Processing Record 7 of Set 7 | cozumel
# Processing Record 8 of Set 7 | fantanele
# Processing Record 9 of Set 7 | muros
# Processing Record 10 of Set 7 | damghan
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | the valley
# Processing Record 13 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 7 | blyth
# Processing Record 15 of Set 7 | lata
# Processing Record 16 of Set 7 | pevek
# Processing Record 17 of Set 7 | oriximina
# Processing Record 18 of Set 7 | borogontsy
# Processing Record 19 of Set 7 | namatanai
# Processing Record 20 of Set 7 | saint-philippe
# Processing Record 21 of Set 7 | jalu
# Processing Record 22 of Set 7 | hanyang
# Processing Record 23 of Set 7 | nanortalik
# Processing Record 24 of Set 7 | tall kayf
# Processing Record 25 of Set 7 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 26 of Set 7 | koungou
# Processing Record 27 of Set 7 | san quintin
# Processing Record 28 of Set 7 | guider
# Processing Record 29 of Set 7 | boa vista
# Processing Record 30 of Set 7 | tubinskiy
# Processing Record 31 of Set 7 | mulege
# Processing Record 32 of Set 7 | vila
# Processing Record 33 of Set 7 | bara
# Processing Record 34 of Set 7 | bell ville
# Processing Record 35 of Set 7 | vao
# Processing Record 36 of Set 7 | awbari
# Processing Record 37 of Set 7 | codrington
# Processing Record 38 of Set 7 | kuito
# Processing Record 39 of Set 7 | antofagasta
# Processing Record 40 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 7 | touros
# Processing Record 42 of Set 7 | monte alegre
# Processing Record 43 of Set 7 | luanda
# Processing Record 44 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 7 | kavieng
# Processing Record 47 of Set 7 | sibolga
# Processing Record 48 of Set 7 | kongolo
# Processing Record 49 of Set 7 | bamako
# Processing Record 50 of Set 7 | cayenne
# Processing Record 1 of Set 8 | peleduy
# Processing Record 2 of Set 8 | tucupita
# Processing Record 3 of Set 8 | stepnyak
# Processing Record 4 of Set 8 | bar
# Processing Record 5 of Set 8 | sept-iles
# Processing Record 6 of Set 8 | oussouye
# Processing Record 7 of Set 8 | campbell river
# Processing Record 8 of Set 8 | korla
# Processing Record 9 of Set 8 | barranca de upia
# Processing Record 10 of Set 8 | rocha
# Processing Record 11 of Set 8 | cabo san lucas
# Processing Record 12 of Set 8 | alexandria
# Processing Record 13 of Set 8 | sur
# Processing Record 14 of Set 8 | khani
# Processing Record 15 of Set 8 | port hardy
# Processing Record 16 of Set 8 | fairbanks
# Processing Record 17 of Set 8 | kaeo
# Processing Record 18 of Set 8 | marovoay
# Processing Record 19 of Set 8 | kisangani
# Processing Record 20 of Set 8 | svetlogorsk
# Processing Record 21 of Set 8 | geraldton
# Processing Record 22 of Set 8 | puerto baquerizo moreno
# Processing Record 23 of Set 8 | hualmay
# Processing Record 24 of Set 8 | malpe
# Processing Record 25 of Set 8 | buraydah
# Processing Record 26 of Set 8 | roma
# Processing Record 27 of Set 8 | khatanga
# Processing Record 28 of Set 8 | valparaiso
# Processing Record 29 of Set 8 | charlestown
# Processing Record 30 of Set 8 | maravilha
# Processing Record 31 of Set 8 | mixquiahuala
# Processing Record 32 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 33 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 8 | centralia
# Processing Record 35 of Set 8 | victoria
# Processing Record 36 of Set 8 | aksu
# Processing Record 37 of Set 8 | kassala
# Processing Record 38 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 8 | atikokan
# Processing Record 40 of Set 8 | constitucion
# Processing Record 41 of Set 8 | olafsvik
# Processing Record 42 of Set 8 | mahebourg
# Processing Record 43 of Set 8 | manvi
# Processing Record 44 of Set 8 | lodwar
# Processing Record 45 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 8 | mount gambier
# Processing Record 47 of Set 8 | cap-aux-meules
# Processing Record 48 of Set 8 | ramnagar
# Processing Record 49 of Set 8 | tsiroanomandidy
# Processing Record 50 of Set 8 | georgetown
# Processing Record 1 of Set 9 | sao filipe
# Processing Record 2 of Set 9 | galveston
# Processing Record 3 of Set 9 | cap malheureux
# Processing Record 4 of Set 9 | uniao
# Processing Record 5 of Set 9 | abu zabad
# Processing Record 6 of Set 9 | sinop
# Processing Record 7 of Set 9 | usinsk
# Processing Record 8 of Set 9 | bayir
# Processing Record 9 of Set 9 | christchurch
# Processing Record 10 of Set 9 | mutis
# Processing Record 11 of Set 9 | san matias
# Processing Record 12 of Set 9 | shimoda
# Processing Record 13 of Set 9 | taos
# Processing Record 14 of Set 9 | jibuti
# Processing Record 15 of Set 9 | verkhnyaya inta
# Processing Record 16 of Set 9 | tocopilla
# Processing Record 17 of Set 9 | danville
# Processing Record 18 of Set 9 | anloga
# Processing Record 19 of Set 9 | mapastepec
# Processing Record 20 of Set 9 | chara
# Processing Record 21 of Set 9 | xinyu
# Processing Record 22 of Set 9 | paamiut
# Processing Record 23 of Set 9 | wanaka
# Processing Record 24 of Set 9 | luderitz
# Processing Record 25 of Set 9 | sawtell
# Processing Record 26 of Set 9 | banjar
# Processing Record 27 of Set 9 | gari
# Processing Record 28 of Set 9 | sungairaya
# Processing Record 29 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 9 | mehran
# Processing Record 31 of Set 9 | walvis bay
# Processing Record 32 of Set 9 | bairiki
# Processing Record 33 of Set 9 | mereni
# Processing Record 34 of Set 9 | asau
# Processing Record 35 of Set 9 | lashio
# Processing Record 36 of Set 9 | aswan
# Processing Record 37 of Set 9 | pahrump
# Processing Record 38 of Set 9 | rawson
# Processing Record 39 of Set 9 | porto seguro
# Processing Record 40 of Set 9 | roseburg
# Processing Record 41 of Set 9 | yumen
# Processing Record 42 of Set 9 | oktyabrskiy
# Processing Record 43 of Set 9 | alta floresta
# Processing Record 44 of Set 9 | akdepe
# Processing Record 45 of Set 9 | esperance
# Processing Record 46 of Set 9 | topeka
# Processing Record 47 of Set 9 | pitkyaranta
# Processing Record 48 of Set 9 | ciro marina
# Processing Record 49 of Set 9 | leeuwarden
# Processing Record 50 of Set 9 | leh
# Processing Record 1 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 10 | canchungo
# Processing Record 3 of Set 10 | montes altos
# Processing Record 4 of Set 10 | kidal
# Processing Record 5 of Set 10 | sohag
# Processing Record 6 of Set 10 | gerash
# Processing Record 7 of Set 10 | birao
# Processing Record 8 of Set 10 | grants pass
# Processing Record 9 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 10 of Set 10 | melilla
# Processing Record 11 of Set 10 | angoche
# Processing Record 12 of Set 10 | consett
# Processing Record 13 of Set 10 | livingston
# Processing Record 14 of Set 10 | moiyabana
# City not found. Skipping...
# Processing Record 15 of Set 10 | lamtah
# Processing Record 16 of Set 10 | ancud
# Processing Record 17 of Set 10 | sisimiut
# Processing Record 18 of Set 10 | mahuva
# Processing Record 19 of Set 10 | metlika
# Processing Record 20 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 10 | athabasca
# Processing Record 23 of Set 10 | barpeta
# Processing Record 24 of Set 10 | yichun
# Processing Record 25 of Set 10 | tungor
# Processing Record 26 of Set 10 | manoel urbano
# Processing Record 27 of Set 10 | uinskoye
# Processing Record 28 of Set 10 | bahir dar
# Processing Record 29 of Set 10 | rantauprapat
# Processing Record 30 of Set 10 | medicine hat
# Processing Record 31 of Set 10 | rohnert park
# Processing Record 32 of Set 10 | vila velha
# Processing Record 33 of Set 10 | ayr
# Processing Record 34 of Set 10 | ouagadougou
# Processing Record 35 of Set 10 | sol-iletsk
# Processing Record 36 of Set 10 | tukrah
# Processing Record 37 of Set 10 | mogadishu
# Processing Record 38 of Set 10 | tevaitoa
# Processing Record 39 of Set 10 | antalaha
# Processing Record 40 of Set 10 | ndjole
# Processing Record 41 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 10 | uruzgan
# Processing Record 43 of Set 10 | jawhar
# Processing Record 44 of Set 10 | pokhara
# Processing Record 45 of Set 10 | onega
# Processing Record 46 of Set 10 | lisakovsk
# Processing Record 47 of Set 10 | ilulissat
# Processing Record 48 of Set 10 | larsnes
# Processing Record 49 of Set 10 | soligalich
# Processing Record 50 of Set 10 | port-gentil
# Processing Record 1 of Set 11 | ouargaye
# Processing Record 2 of Set 11 | vardo
# Processing Record 3 of Set 11 | perelyub
# Processing Record 4 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 11 | batagay-alyta
# Processing Record 6 of Set 11 | sabha
# Processing Record 7 of Set 11 | sarkand
# Processing Record 8 of Set 11 | atambua
# Processing Record 9 of Set 11 | la paz
# Processing Record 10 of Set 11 | coxim
# Processing Record 11 of Set 11 | at-bashi
# Processing Record 12 of Set 11 | tawang
# Processing Record 13 of Set 11 | paita
# Processing Record 14 of Set 11 | kashira
# Processing Record 15 of Set 11 | ambovombe
# Processing Record 16 of Set 11 | nata
# Processing Record 17 of Set 11 | merauke
# Processing Record 18 of Set 11 | verkhnevilyuysk
# Processing Record 19 of Set 11 | harper
# Processing Record 20 of Set 11 | alyangula
# Processing Record 21 of Set 11 | acapulco
# Processing Record 22 of Set 11 | darovskoy
# Processing Record 23 of Set 11 | gombe
# Processing Record 24 of Set 11 | hovd
# Processing Record 25 of Set 11 | aalsmeer
# Processing Record 26 of Set 11 | karachi
# Processing Record 27 of Set 11 | cabedelo
# Processing Record 28 of Set 11 | liverpool
# Processing Record 29 of Set 11 | las palmas
# Processing Record 30 of Set 11 | duz
# City not found. Skipping...
# Processing Record 31 of Set 11 | yulara
# Processing Record 32 of Set 11 | pemangkat
# Processing Record 33 of Set 11 | mega
# Processing Record 34 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 11 | makakilo city
# Processing Record 36 of Set 11 | ossora
# Processing Record 37 of Set 11 | diego de almagro
# Processing Record 38 of Set 11 | san andres
# Processing Record 39 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 11 | marapanim
# Processing Record 41 of Set 11 | dondo
# Processing Record 42 of Set 11 | elko
# Processing Record 43 of Set 11 | beyneu
# Processing Record 44 of Set 11 | sao gabriel da cachoeira
# Processing Record 45 of Set 11 | xai-xai
# Processing Record 46 of Set 11 | grenaa
# Processing Record 47 of Set 11 | biggar
# Processing Record 48 of Set 11 | monywa
# Processing Record 49 of Set 11 | nouadhibou
# Processing Record 50 of Set 11 | calbuco
# Processing Record 1 of Set 12 | ampanihy
# Processing Record 2 of Set 12 | tawau
# Processing Record 3 of Set 12 | egvekinot
# Processing Record 4 of Set 12 | xining
# Processing Record 5 of Set 12 | nurlat
# Processing Record 6 of Set 12 | mildura
# Processing Record 7 of Set 12 | khanu woralaksaburi
# Processing Record 8 of Set 12 | san jose del golfo
# Processing Record 9 of Set 12 | fare
# Processing Record 10 of Set 12 | moramanga
# Processing Record 11 of Set 12 | zhigansk
# Processing Record 12 of Set 12 | yunjinghong
# City not found. Skipping...
# Processing Record 13 of Set 12 | de-kastri
# Processing Record 14 of Set 12 | ignatovka
# Processing Record 15 of Set 12 | helong
# Processing Record 16 of Set 12 | mayen
# Processing Record 17 of Set 12 | bodoco
# City not found. Skipping...
# Processing Record 18 of Set 12 | santiago del estero
# Processing Record 19 of Set 12 | port arthur
# Processing Record 20 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 12 | edson
# Processing Record 22 of Set 12 | teyateyaneng
# Processing Record 23 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 12 | sichevita
# Processing Record 25 of Set 12 | madridejos
# Processing Record 26 of Set 12 | luena
# Processing Record 27 of Set 12 | takoradi
# Processing Record 28 of Set 12 | santa maria
# Processing Record 29 of Set 12 | safaga
# Processing Record 30 of Set 12 | qui nhon
# Processing Record 31 of Set 12 | faya
# Processing Record 32 of Set 12 | ermioni
# Processing Record 33 of Set 12 | alugan
# Processing Record 34 of Set 12 | katangli
# Processing Record 35 of Set 12 | nakasongola
# Processing Record 36 of Set 12 | temerloh
# Processing Record 37 of Set 12 | kununurra
# Processing Record 38 of Set 12 | kungurtug
# Processing Record 39 of Set 12 | liniere
# City not found. Skipping...
# Processing Record 40 of Set 12 | tadine
# Processing Record 41 of Set 12 | andenes
# Processing Record 42 of Set 12 | manado
# Processing Record 43 of Set 12 | dakar
# Processing Record 44 of Set 12 | mouzakion
# City not found. Skipping...
# Processing Record 45 of Set 12 | slave lake
# Processing Record 46 of Set 12 | neyshabur
# Processing Record 47 of Set 12 | yaan
# Processing Record 48 of Set 12 | gorontalo
# Processing Record 49 of Set 12 | grafton
# Processing Record 50 of Set 12 | batangafo
# Processing Record 1 of Set 13 | masuguru
# Processing Record 2 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 3 of Set 13 | abu dhabi
# Processing Record 4 of Set 13 | malanje
# Processing Record 5 of Set 13 | bilgoraj
# Processing Record 6 of Set 13 | lokomotivnyy
# Processing Record 7 of Set 13 | santarem
# Processing Record 8 of Set 13 | camacupa
# Processing Record 9 of Set 13 | morales
# Processing Record 10 of Set 13 | samarai
# Processing Record 11 of Set 13 | atar
# Processing Record 12 of Set 13 | dongsheng
# Processing Record 13 of Set 13 | pemberton
# Processing Record 14 of Set 13 | general pico
# Processing Record 15 of Set 13 | jutai
# Processing Record 16 of Set 13 | kerema
# Processing Record 17 of Set 13 | makriyialos
# City not found. Skipping...
# Processing Record 18 of Set 13 | mackay
# Processing Record 19 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 13 | hibbing
# Processing Record 21 of Set 13 | oparino
# Processing Record 22 of Set 13 | barreirinhas
# Processing Record 23 of Set 13 | tari
# Processing Record 24 of Set 13 | chardara
# Processing Record 25 of Set 13 | sibu
# Processing Record 26 of Set 13 | eucaliptus
# Processing Record 27 of Set 13 | langsa
# Processing Record 28 of Set 13 | nunoa
# Processing Record 29 of Set 13 | ballina
# Processing Record 30 of Set 13 | yingkou
# Processing Record 31 of Set 13 | isangel
# Processing Record 32 of Set 13 | helena
# Processing Record 33 of Set 13 | comodoro rivadavia
# Processing Record 34 of Set 13 | xam nua
# Processing Record 35 of Set 13 | camacha
# Processing Record 36 of Set 13 | port moresby
# Processing Record 37 of Set 13 | ulagan
# Processing Record 38 of Set 13 | meulaboh
# Processing Record 39 of Set 13 | baoqing
# Processing Record 40 of Set 13 | yazd
# Processing Record 41 of Set 13 | seymchan
# Processing Record 42 of Set 13 | okhotsk
# Processing Record 43 of Set 13 | maceio
# Processing Record 44 of Set 13 | champagnole
# Processing Record 45 of Set 13 | timmins
# Processing Record 46 of Set 13 | jalor
# Processing Record 47 of Set 13 | aklavik
# Processing Record 48 of Set 13 | khandyga
# Processing Record 49 of Set 13 | waipawa
# Processing Record 50 of Set 13 | hearst
# Processing Record 1 of Set 14 | nueva loja
# Processing Record 2 of Set 14 | panixtlahuaca
# City not found. Skipping...
# Processing Record 3 of Set 14 | quatre cocos
# Processing Record 4 of Set 14 | gravelbourg
# Processing Record 5 of Set 14 | lyskovo
# Processing Record 6 of Set 14 | vyartsilya
# Processing Record 7 of Set 14 | aykhal
# Processing Record 8 of Set 14 | dhidhdhoo
# Processing Record 9 of Set 14 | mabaruma
# Processing Record 10 of Set 14 | velikodvorskiy
# Processing Record 11 of Set 14 | vila franca do campo
# Processing Record 12 of Set 14 | thano bula khan
# City not found. Skipping...
# Processing Record 13 of Set 14 | tura
# Processing Record 14 of Set 14 | belmonte
# Processing Record 15 of Set 14 | ponta delgada
# Processing Record 16 of Set 14 | tripoli
# Processing Record 17 of Set 14 | ewa beach
# Processing Record 18 of Set 14 | virginia beach
# Processing Record 19 of Set 14 | northam
# Processing Record 20 of Set 14 | tessaoua
# Processing Record 21 of Set 14 | lieksa
# Processing Record 22 of Set 14 | west odessa
# Processing Record 23 of Set 14 | spearfish
# Processing Record 24 of Set 14 | clarksburg
# Processing Record 25 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 26 of Set 14 | agua verde
# Processing Record 27 of Set 14 | bereda
# Processing Record 28 of Set 14 | camrose
# Processing Record 29 of Set 14 | uruacu
# Processing Record 30 of Set 14 | morden
# Processing Record 31 of Set 14 | karratha
# Processing Record 32 of Set 14 | ringebu
# Processing Record 33 of Set 14 | newport
# Processing Record 34 of Set 14 | baykit
# Processing Record 35 of Set 14 | lorengau
# Processing Record 36 of Set 14 | san isidro
# Processing Record 37 of Set 14 | nasice
# Processing Record 38 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 39 of Set 14 | mpika
# Processing Record 40 of Set 14 | praxedis guerrero
# Processing Record 41 of Set 14 | amapa
# Processing Record 42 of Set 14 | sakaide
# Processing Record 43 of Set 14 | ko samui
# Processing Record 44 of Set 14 | strezhevoy
# Processing Record 45 of Set 14 | yushu
# Processing Record 46 of Set 14 | mountain home
# Processing Record 47 of Set 14 | buzmeyin
# Processing Record 48 of Set 14 | kalispell
# Processing Record 49 of Set 14 | valjala
# City not found. Skipping...
# Processing Record 50 of Set 14 | chiesanuova
# Processing Record 1 of Set 15 | plerin
# Processing Record 2 of Set 15 | goderich
# Processing Record 3 of Set 15 | pangoa
# Processing Record 4 of Set 15 | finschhafen
# Processing Record 5 of Set 15 | witu
# Processing Record 6 of Set 15 | kabinda
# Processing Record 7 of Set 15 | balclutha
# Processing Record 8 of Set 15 | ishigaki
# Processing Record 9 of Set 15 | saint-pierre
# Processing Record 10 of Set 15 | matlang
# Processing Record 11 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 12 of Set 15 | panjab
# Processing Record 13 of Set 15 | yinchuan
# Processing Record 14 of Set 15 | honiara
# Processing Record 15 of Set 15 | kirkland lake
# Processing Record 16 of Set 15 | minot
# Processing Record 17 of Set 15 | sadiqabad
# Processing Record 18 of Set 15 | charters towers
# Processing Record 19 of Set 15 | bela
# Processing Record 20 of Set 15 | kendari
# Processing Record 21 of Set 15 | kerrville
# Processing Record 22 of Set 15 | morondava
# Processing Record 23 of Set 15 | toulepleu
# City not found. Skipping...
# Processing Record 24 of Set 15 | burnie
# Processing Record 25 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 26 of Set 15 | lumeje
# Processing Record 27 of Set 15 | kosonsoy
# Processing Record 28 of Set 15 | mascote
# Processing Record 29 of Set 15 | olenino
# Processing Record 30 of Set 15 | basco
# Processing Record 31 of Set 15 | tovste
# Processing Record 32 of Set 15 | borba
# Processing Record 33 of Set 15 | saint-leu
# Processing Record 34 of Set 15 | balsas
# Processing Record 35 of Set 15 | dromolaxia
# Processing Record 36 of Set 15 | cairns
# Processing Record 37 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 15 | taoudenni
# Processing Record 39 of Set 15 | dosso
# Processing Record 40 of Set 15 | bonavista
# Processing Record 41 of Set 15 | gualeguaychu
# Processing Record 42 of Set 15 | luangwa
# Processing Record 43 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 15 | miranda
# Processing Record 45 of Set 15 | duncan
# Processing Record 46 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 15 | balikpapan
# Processing Record 48 of Set 15 | damavand
# Processing Record 49 of Set 15 | ayan
# Processing Record 50 of Set 15 | koygorodok
# Processing Record 1 of Set 16 | sampang
# Processing Record 2 of Set 16 | cape girardeau
# Processing Record 3 of Set 16 | skalistyy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hasaki  35.7333  140.8333     48.49        56         100
# 1        Tsumeb -19.2333   17.7167     74.75        25          35
# 2        Kodiak  57.7900 -152.4072     20.71        93          90
# 3       Mataura -46.1927  168.8643     50.49        98         100
# 4          Hilo  19.7297 -155.0900     70.25        93          90
# 5        Tirano  46.2154   10.1679     38.61        99         100
# 6  Abrau-Dyurso  44.6900   37.5900     45.86        90         100
# 7       Rikitea -23.1203 -134.9692     75.63        78          97
# 8        Albany  42.6001  -73.9662     35.55        79          88
# 9          Naze  28.3667  129.4833     61.72        68         100
#
#    Wind Speed Country Current Description                 Date
# 0        9.28      JP     overcast clouds  2021-12-05 07:36:38
# 1       11.41      NA    scattered clouds  2021-12-05 07:36:39
# 2        3.44      US     overcast clouds  2021-12-05 07:36:37
# 3        2.15      NZ          light rain  2021-12-05 07:36:39
# 4        4.61      US     overcast clouds  2021-12-05 07:34:16
# 5        6.64      IT     overcast clouds  2021-12-05 07:36:40
# 6        7.18      RU     overcast clouds  2021-12-05 07:36:40
# 7        9.15      PF     overcast clouds  2021-12-05 07:36:40
# 8        5.91      US     overcast clouds  2021-12-05 07:36:41
# 9       15.05      JP     overcast clouds  2021-12-05 07:36:41

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df=city_data_df[new_column_order]
city_data_df.Lat = city_data_df.Lat.round(2)
city_data_df.Lng = city_data_df.Lng.round(2)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hasaki      JP  35.73  140.83     48.49        56         100
# 1        Tsumeb      NA -19.23   17.72     74.75        25          35
# 2        Kodiak      US  57.79 -152.41     20.71        93          90
# 3       Mataura      NZ -46.19  168.86     50.49        98         100
# 4          Hilo      US  19.73 -155.09     70.25        93          90
# 5        Tirano      IT  46.22   10.17     38.61        99         100
# 6  Abrau-Dyurso      RU  44.69   37.59     45.86        90         100
# 7       Rikitea      PF -23.12 -134.97     75.63        78          97
# 8        Albany      US  42.60  -73.97     35.55        79          88
# 9          Naze      JP  28.37  129.48     61.72        68         100
#
#    Wind Speed Current Description
# 0        9.28     overcast clouds
# 1       11.41    scattered clouds
# 2        3.44     overcast clouds
# 3        2.15          light rain
# 4        4.61     overcast clouds
# 5        6.64     overcast clouds
# 6        7.18     overcast clouds
# 7        9.15     overcast clouds
# 8        5.91     overcast clouds
# 9       15.05     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

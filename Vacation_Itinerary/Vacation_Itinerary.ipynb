# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import gmaps.datasets

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("..\Vacation_Search/WeatherPy_vacation.csv")
vacation_df.tail(50)
# Out:
#      City_ID                 City Country  Max Temp   Current Description  \
# 112      486            Pemangkat      ID     81.09       overcast clouds
# 113      491           San Andres      CO     81.79       overcast clouds
# 114      493                Dondo      MZ     89.11             clear sky
# 115      500               Monywa      MM     82.33       overcast clouds
# 116      504                Tawau      MY     86.13      scattered clouds
# 117      508              Mildura      AU     80.56       overcast clouds
# 118      509  Khanu Woralaksaburi      TH     78.64         broken clouds
# 119      511                 Fare      PF     81.16         broken clouds
# 120      512            Moramanga      MG     84.06             clear sky
# 121      525             Takoradi      GH     82.49      scattered clouds
# 122      527               Safaga      EG     76.95       overcast clouds
# 123      531               Alugan      PH     79.36         broken clouds
# 124      533          Nakasongola      UG     80.82         broken clouds
# 125      534             Temerloh      MY     83.44            light rain
# 126      539               Manado      ID     81.37      scattered clouds
# 127      544            Gorontalo      ID     83.53       overcast clouds
# 128      548            Abu Dhabi      AE     77.11            few clouds
# 129      549              Malanje      AO     75.20            light rain
# 130      555              Samarai      PG     83.50       overcast clouds
# 131      561               Kerema      PG     80.67       overcast clouds
# 132      562               Mackay      AU     84.18             clear sky
# 133      568                 Sibu      MY     80.91         moderate rain
# 134      570               Langsa      ID     81.32         moderate rain
# 135      574              Isangel      VU     77.56       overcast clouds
# 136      579         Port Moresby      PG     85.42         broken clouds
# 137      581             Meulaboh      ID     84.25       overcast clouds
# 138      586               Maceio      BR     78.24         broken clouds
# 139      589                Jalor      IN     79.30         broken clouds
# 140      595         Quatre Cocos      MU     85.08            few clouds
# 141      600            Dhidhdhoo      MV     82.38         broken clouds
# 142      604                 Tura      IN     76.42       overcast clouds
# 143      611             Tessaoua      NE     76.26         broken clouds
# 144      625             Lorengau      PG     83.07  heavy intensity rain
# 145      628                Mpika      ZM     84.88             clear sky
# 146      632             Ko Samui      TH     85.91            few clouds
# 147      642          Finschhafen      PG     81.54       overcast clouds
# 148      644              Kabinda      CD     80.38            light rain
# 149      647         Saint-Pierre      RE     86.18            few clouds
# 150      648              Matlang      PH     81.48       overcast clouds
# 151      651              Honiara      SB     79.75       overcast clouds
# 152      654            Sadiqabad      PK     81.03             clear sky
# 153      655      Charters Towers      AU     87.15         broken clouds
# 154      656                 Bela      IN     82.92             clear sky
# 155      657              Kendari      ID     83.98       overcast clouds
# 156      659            Morondava      MG     86.50             clear sky
# 157      665                Basco      PH     75.49       overcast clouds
# 158      668            Saint-Leu      RE     85.57            few clouds
# 159      673                Dosso      NE     77.52       overcast clouds
# 160      679           Balikpapan      ID     85.19            few clouds
# 161      683              Sampang      ID     87.75            light rain
#
#        Lat     Lng                           Hotel Name
# 112   1.17  108.97                      Ramah Kost KITA
# 113  12.58  -81.70                   Hotel Arena Blanca
# 114 -19.61   34.74                            Arco Iris
# 115  22.12   95.13                         Monywa Hotel
# 116   4.25  117.89  Shervinton Executive Boutique Hotel
# 117 -34.20  142.15                Mercure Hotel Mildura
# 118  16.06   99.86          แฟลตตำรวจ บ้านดาบโก ดอกฝิ่น
# 119 -16.70 -151.02        Maitai Lapita Village Huahine
# 120 -18.93   48.20                       Espace VANILLA
# 121   4.88   -1.76           Raybow International Hotel
# 122  26.73   33.94                Lamar Resort Abu Soma
# 123  12.22  125.48                             JM Lodge
# 124   1.31   32.46             Norena Hotel Nakasongola
# 125   3.45  102.42              U Design Hotel Temerloh
# 126   1.49  124.85                       Aryaduta Hotel
# 127   0.54  123.06             Maqna Hotel by Prasanthi
# 128  24.47   54.37             Mourouj Hotel Apartments
# 129  -9.54   16.34                        Malanje Hotel
# 130 -10.62  150.67                            Nuli Sapi
# 131  -7.96  145.78                          Frena Lodge
# 132 -21.15  149.20            International Lodge Motel
# 133   2.30  111.82                    RH HOTEL (4 Star)
# 134   4.47   97.97                 OYO 2964 Hotel Ridho
# 135 -19.55  169.27                          Tanna Lodge
# 136  -9.44  147.18          Lamana Hotel (Port Moresby)
# 137   4.14   96.13                            Kost Pria
# 138  -9.67  -35.74                       Poutur Pousada
# 139  25.35   72.62                     Hotel Mansarovar
# 140 -20.21   57.76               Sunrise Attitude Hotel
# 141   6.88   73.10                        Dhidhoo beach
# 142  25.52   90.22             Hotel RIKMAN Continental
# 143  13.76    7.99             Benin Dan Kaabou Heberge
# 144  -2.02  147.27           Lorengau Harbourside Hotel
# 145 -11.83   31.45                       Melodies Lodge
# 146   9.54   99.94                          The Passage
# 147  -6.60  147.87                   Cossam Guest House
# 148  -6.13   24.48                Village Mianda Mutole
# 149 -21.34   55.48                        Lindsey Hôtel
# 150  10.89  124.46     JB's Collection & Mangrove Place
# 151  -9.43  159.95                  Heritage Park Hotel
# 152  28.31   70.13            MIDWAY HOTEL & RESTAURANT
# 153 -20.10  146.27           Cattleman's Rest Motor Inn
# 154  25.93   81.98                      Siddharth Hotel
# 155  -3.94  122.50                          Hotel Wixel
# 156 -20.28   44.28                       La Case Bambou
# 157  20.45  121.97                    Nathaniel's Lodge
# 158 -21.15   55.28                        La Caz Oceane
# 159  13.05    3.19                         Hotel Toubal
# 160  -1.27  116.83            Swiss-Belhotel Balikpapan
# 161  -7.19  113.24                sekretariat IKA STAIN

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.4)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Antalaha"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Antalaha"]
vacation_stop1 = vacation_df.loc[vacation_df['City'] == "Moramanga"]
vacation_stop2 = vacation_df.loc[vacation_df['City'] == "Vangaindrano"]
vacation_stop3 = vacation_df.loc[vacation_df['City'] == "Morondava"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]
print (start, end, stop1, stop2, stop3)
# Out:
# (-14.9, 50.28) (-14.9, 50.28) (-18.93, 48.2) (-23.35, 47.6) (-20.28, 44.28)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure(center=(-16.70, 48.2), zoom_level=5.30)
vacation_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2,stop3],
        travel_mode='DRIVING')


fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID          City Country  Max Temp Current Description    Lat    Lng  \
# 0      446      Antalaha      MG     84.79          few clouds -14.90  50.28
# 1      512     Moramanga      MG     84.06           clear sky -18.93  48.20
# 2      207  Vangaindrano      MG     87.84           clear sky -23.35  47.60
# 3      659     Morondava      MG     86.50           clear sky -20.28  44.28
#
#        Hotel Name
# 0   Hotel Vitasoa
# 1  Espace VANILLA
# 2    Hotel Fanilo
# 3  La Case Bambou

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
city_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(-16.70, 48.2), zoom_level=5.25)
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
 #            max_intensity=300, point_radius=2)
marker_layer = gmaps.marker_layer(locations, info_box_content=city_info)
#fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
